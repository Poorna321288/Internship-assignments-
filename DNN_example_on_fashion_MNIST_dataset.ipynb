# %% [markdown]
# <a href="https://colab.research.google.com/github/Poorna321288/Internship-assignments-/blob/main/DNN_example_on_fashion_MNIST_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization,Dropout

from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Add, Activation, Flatten
from tensorflow.keras.utils import to_categorical
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
x_train_flat = x_train.reshape(-1, 28*28)
x_test_flat = x_test.reshape(-1, 28*28)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[np.argmax(y_train[i])])
plt.show()

# %%
def create_dnn():
    inputs = Input(shape=(784,))
    x = Dense(512, activation='relu')(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)


    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    x = Dense(64, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.1)(x)

    outputs = Dense(10, activation='softmax')(x)
    return Model(inputs, outputs)

# %%
def create_resnet_dnn():
    inputs = Input(shape=(784,))


    x = Dense(256)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.4)(x)


    x1 = Dense(256)(x)
    x1 = BatchNormalization()(x1)
    x1 = Activation('relu')(x1)
    x1 = Dropout(0.4)(x1)

    x2 = Dense(256)(x1)
    x2 = BatchNormalization()(x2)

    res1 = Add()([x, x2])
    res1 = Activation('relu')(res1)
    res1 = Dropout(0.3)(res1)


    x3 = Dense(128)(res1)
    x3 = BatchNormalization()(x3)
    x3 = Activation('relu')(x3)
    x3 = Dropout(0.2)(x3)

    x4 = Dense(128)(x3)
    x4 = BatchNormalization()(x4)
    res1_proj = Dense(128)(res1)
    res2 = Add()([res1_proj, x4])
    res2 = Activation('relu')(res2)
    res2 = Dropout(0.1)(res2)
    x5 = Dense(128)(res2)
    x5 = BatchNormalization()(x5)
    x5 = Activation('relu')(x5)
    x5 = Dropout(0.2)(x5)

    x6 = Dense(128)(x5)
    x6 = BatchNormalization()(x6)

    res2_proj = Dense(128)(res2)
    res3 = Add()([res2_proj, x6])
    res3 = Activation('relu')(res3)
    res3 = Dropout(0.1)(res3)


    x7 = Dense(64)(res3)
    x7 = BatchNormalization()(x7)
    x7 = Activation('relu')(x7)
    x7 = Dropout(0.1)(x7)

    x8 = Dense(64)(x7)
    x8 = BatchNormalization()(x8)

    res3_proj = Dense(64)(res3)
    res4 = Add()([res3_proj, x8])
    res4 = Activation('relu')(res4)
    res4 = Dropout(0.1)(res4)

    x_final = Dense(64, activation='relu')(res4)
    x_final = BatchNormalization()(x_final)
    outputs = Dense(10, activation='softmax')(x_final)
    return Model(inputs, outputs)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

dnn_model = create_dnn()
resnet_model = create_resnet_dnn()
early = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

dnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
resnet_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'],)

# %%
dnn_history = dnn_model.fit(x_train_flat, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_split=0.1,
                           callbacks=[early, lr_reduce],

                            verbose=1)

resnet_history = resnet_model.fit(x_train_flat, y_train,
                                 epochs=50,
                                 batch_size=256,
                                 validation_split=0.1,
                                  callbacks=[early, lr_reduce],
                                 verbose=1)
# Out:
# Epoch 1/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - accuracy: 0.5178 - loss: 1.4078 - val_accuracy: 0.7998 - val_loss: 0.5429 - learning_rate: 0.0010
# Epoch 2/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8043 - loss: 0.5553 - val_accuracy: 0.8512 - val_loss: 0.4200 - learning_rate: 0.0010
# Epoch 3/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 52ms/step - accuracy: 0.8279 - loss: 0.4859 - val_accuracy: 0.8383 - val_loss: 0.4492 - learning_rate: 0.0010
# Epoch 4/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - accuracy: 0.8379 - loss: 0.4521 - val_accuracy: 0.8573 - val_loss: 0.3907 - learning_rate: 0.0010
# Epoch 5/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - accuracy: 0.8419 - loss: 0.4390 - val_accuracy: 0.8547 - val_loss: 0.4026 - learning_rate: 0.0010
# Epoch 6/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - accuracy: 0.8492 - loss: 0.4191 - val_accuracy: 0.8603 - val_loss: 0.3850 - learning_rate: 0.0010
# Epoch 7/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - accuracy: 0.8541 - loss: 0.4108 - val_accuracy: 0.8577 - val_loss: 0.4084 - learning_rate: 0.0010
# Epoch 8/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.8544 - loss: 0.4080 - val_accuracy: 0.8677 - val_loss: 0.3744 - learning_rate: 0.0010
# Epoch 9/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - accuracy: 0.8580 - loss: 0.3946 - val_accuracy: 0.8700 - val_loss: 0.3538 - learning_rate: 0.0010
# Epoch 10/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - accuracy: 0.8584 - loss: 0.3907 - val_accuracy: 0.8678 - val_loss: 0.3573 - learning_rate: 0.0010
# Epoch 11/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.8619 - loss: 0.3867 - val_accuracy: 0.8683 - val_loss: 0.3578 - learning_rate: 0.0010
# Epoch 12/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8654 - loss: 0.3743 - val_accuracy: 0.8730 - val_loss: 0.3481 - learning_rate: 0.0010
# Epoch 13/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.8669 - loss: 0.3671 - val_accuracy: 0.8787 - val_loss: 0.3468 - learning_rate: 0.0010
# Epoch 14/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.8656 - loss: 0.3724 - val_accuracy: 0.8797 - val_loss: 0.3323 - learning_rate: 0.0010
# Epoch 15/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - accuracy: 0.8716 - loss: 0.3579 - val_accuracy: 0.8755 - val_loss: 0.3430 - learning_rate: 0.0010
# Epoch 16/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.8746 - loss: 0.3523 - val_accuracy: 0.8802 - val_loss: 0.3389 - learning_rate: 0.0010
# Epoch 17/50
# 210/211 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8747 - loss: 0.3494
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.8747 - loss: 0.3495 - val_accuracy: 0.8743 - val_loss: 0.3332 - learning_rate: 0.0010
# Epoch 18/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.8768 - loss: 0.3377 - val_accuracy: 0.8883 - val_loss: 0.3176 - learning_rate: 5.0000e-04
# Epoch 19/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - accuracy: 0.8828 - loss: 0.3232 - val_accuracy: 0.8862 - val_loss: 0.3190 - learning_rate: 5.0000e-04
# Epoch 20/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.8874 - loss: 0.3143 - val_accuracy: 0.8858 - val_loss: 0.3195 - learning_rate: 5.0000e-04
# Epoch 21/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.8849 - loss: 0.3159 - val_accuracy: 0.8895 - val_loss: 0.3093 - learning_rate: 5.0000e-04
# Epoch 22/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - accuracy: 0.8858 - loss: 0.3151 - val_accuracy: 0.8852 - val_loss: 0.3158 - learning_rate: 5.0000e-04
# Epoch 23/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 52ms/step - accuracy: 0.8870 - loss: 0.3118 - val_accuracy: 0.8845 - val_loss: 0.3156 - learning_rate: 5.0000e-04
# Epoch 24/50
# 210/211 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8864 - loss: 0.3098
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - accuracy: 0.8864 - loss: 0.3098 - val_accuracy: 0.8867 - val_loss: 0.3115 - learning_rate: 5.0000e-04
# Epoch 25/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.8905 - loss: 0.3000 - val_accuracy: 0.8898 - val_loss: 0.3075 - learning_rate: 2.5000e-04
# Epoch 26/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.8959 - loss: 0.2885 - val_accuracy: 0.8932 - val_loss: 0.3032 - learning_rate: 2.5000e-04
# Epoch 27/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.8971 - loss: 0.2869 - val_accuracy: 0.8880 - val_loss: 0.3109 - learning_rate: 2.5000e-04
# Epoch 28/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - accuracy: 0.8945 - loss: 0.2919 - val_accuracy: 0.8915 - val_loss: 0.3054 - learning_rate: 2.5000e-04
# Epoch 29/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8956 - loss: 0.2861
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.8956 - loss: 0.2861 - val_accuracy: 0.8885 - val_loss: 0.3125 - learning_rate: 2.5000e-04
# Epoch 30/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.8979 - loss: 0.2787 - val_accuracy: 0.8932 - val_loss: 0.2998 - learning_rate: 1.2500e-04
# Epoch 31/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.9021 - loss: 0.2707 - val_accuracy: 0.8947 - val_loss: 0.2989 - learning_rate: 1.2500e-04
# Epoch 32/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - accuracy: 0.8979 - loss: 0.2775 - val_accuracy: 0.8940 - val_loss: 0.3009 - learning_rate: 1.2500e-04
# Epoch 33/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.8993 - loss: 0.2751 - val_accuracy: 0.8925 - val_loss: 0.2992 - learning_rate: 1.2500e-04
# Epoch 34/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - accuracy: 0.8996 - loss: 0.2722 - val_accuracy: 0.8923 - val_loss: 0.2969 - learning_rate: 1.2500e-04
# Epoch 35/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - accuracy: 0.9031 - loss: 0.2668 - val_accuracy: 0.8930 - val_loss: 0.2988 - learning_rate: 1.2500e-04
# Epoch 36/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 22s 55ms/step - accuracy: 0.9042 - loss: 0.2657 - val_accuracy: 0.8937 - val_loss: 0.2973 - learning_rate: 1.2500e-04
# Epoch 37/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9054 - loss: 0.2648
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.9054 - loss: 0.2648 - val_accuracy: 0.8927 - val_loss: 0.2981 - learning_rate: 1.2500e-04
# Epoch 38/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.9046 - loss: 0.2647 - val_accuracy: 0.8940 - val_loss: 0.2982 - learning_rate: 6.2500e-05
# Epoch 39/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - accuracy: 0.9051 - loss: 0.2654 - val_accuracy: 0.8938 - val_loss: 0.2979 - learning_rate: 6.2500e-05
# Epoch 1/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.5311 - loss: 1.3423 - val_accuracy: 0.8197 - val_loss: 0.5059 - learning_rate: 0.0010
# Epoch 2/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 18s 41ms/step - accuracy: 0.7994 - loss: 0.5662 - val_accuracy: 0.8472 - val_loss: 0.4146 - learning_rate: 0.0010
# Epoch 3/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.8272 - loss: 0.4897 - val_accuracy: 0.8602 - val_loss: 0.3928 - learning_rate: 0.0010
# Epoch 4/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.8447 - loss: 0.4460 - val_accuracy: 0.8612 - val_loss: 0.3850 - learning_rate: 0.0010
# Epoch 5/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 19s 41ms/step - accuracy: 0.8506 - loss: 0.4243 - val_accuracy: 0.8708 - val_loss: 0.3609 - learning_rate: 0.0010
# Epoch 6/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.8560 - loss: 0.4021 - val_accuracy: 0.8722 - val_loss: 0.3541 - learning_rate: 0.0010
# Epoch 7/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8628 - loss: 0.3864 - val_accuracy: 0.8780 - val_loss: 0.3422 - learning_rate: 0.0010
# Epoch 8/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.8672 - loss: 0.3687 - val_accuracy: 0.8720 - val_loss: 0.3561 - learning_rate: 0.0010
# Epoch 9/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8714 - loss: 0.3612 - val_accuracy: 0.8660 - val_loss: 0.3724 - learning_rate: 0.0010
# Epoch 10/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8756 - loss: 0.3490
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 41ms/step - accuracy: 0.8756 - loss: 0.3490 - val_accuracy: 0.8672 - val_loss: 0.3820 - learning_rate: 0.0010
# Epoch 11/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 43ms/step - accuracy: 0.8826 - loss: 0.3298 - val_accuracy: 0.8852 - val_loss: 0.3187 - learning_rate: 5.0000e-04
# Epoch 12/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.8864 - loss: 0.3153 - val_accuracy: 0.8807 - val_loss: 0.3212 - learning_rate: 5.0000e-04
# Epoch 13/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.8900 - loss: 0.3083 - val_accuracy: 0.8870 - val_loss: 0.3192 - learning_rate: 5.0000e-04
# Epoch 14/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8937 - loss: 0.2998 - val_accuracy: 0.8847 - val_loss: 0.3124 - learning_rate: 5.0000e-04
# Epoch 15/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8916 - loss: 0.3036 - val_accuracy: 0.8858 - val_loss: 0.3164 - learning_rate: 5.0000e-04
# Epoch 16/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 0.8913 - loss: 0.2987 - val_accuracy: 0.8898 - val_loss: 0.3238 - learning_rate: 5.0000e-04
# Epoch 17/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 42ms/step - accuracy: 0.8946 - loss: 0.2963 - val_accuracy: 0.8910 - val_loss: 0.3114 - learning_rate: 5.0000e-04
# Epoch 18/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8952 - loss: 0.2907 - val_accuracy: 0.8890 - val_loss: 0.3106 - learning_rate: 5.0000e-04
# Epoch 19/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.8988 - loss: 0.2788 - val_accuracy: 0.8922 - val_loss: 0.3056 - learning_rate: 5.0000e-04
# Epoch 20/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.8997 - loss: 0.2797 - val_accuracy: 0.8910 - val_loss: 0.3059 - learning_rate: 5.0000e-04
# Epoch 21/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9020 - loss: 0.2747 - val_accuracy: 0.8878 - val_loss: 0.3130 - learning_rate: 5.0000e-04
# Epoch 22/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9009 - loss: 0.2761
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9009 - loss: 0.2761 - val_accuracy: 0.8890 - val_loss: 0.3225 - learning_rate: 5.0000e-04
# Epoch 23/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - accuracy: 0.9082 - loss: 0.2547 - val_accuracy: 0.8968 - val_loss: 0.2989 - learning_rate: 2.5000e-04
# Epoch 24/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9087 - loss: 0.2546 - val_accuracy: 0.8925 - val_loss: 0.3062 - learning_rate: 2.5000e-04
# Epoch 25/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step - accuracy: 0.9092 - loss: 0.2505 - val_accuracy: 0.8955 - val_loss: 0.3018 - learning_rate: 2.5000e-04
# Epoch 26/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9112 - loss: 0.2466
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9112 - loss: 0.2466 - val_accuracy: 0.8950 - val_loss: 0.3005 - learning_rate: 2.5000e-04
# Epoch 27/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.9131 - loss: 0.2423 - val_accuracy: 0.8972 - val_loss: 0.3042 - learning_rate: 1.2500e-04
# Epoch 28/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 0.9172 - loss: 0.2337 - val_accuracy: 0.8985 - val_loss: 0.3022 - learning_rate: 1.2500e-04

# %%
def plot_history(history, title):
    plt.figure(figsize=(12, 4))
    plt.suptitle(title)

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.legend()

    plt.show()
plot_history(dnn_history, 'Standard DNN Training')
plot_history(resnet_history, 'ResNet-style DNN Training')

# %%
dnn_test_loss, dnn_test_acc = dnn_model.evaluate(x_test_flat, y_test, verbose=0)
resnet_test_loss, resnet_test_acc = resnet_model.evaluate(x_test_flat, y_test, verbose=0)
print(f"Standard DNN Test Accuracy: {dnn_test_acc:.4f}")
print(f"ResNet-style DNN Test Accuracy: {resnet_test_acc:.4f}")
# Out:
# Standard DNN Test Accuracy: 0.8880
# ResNet-style DNN Test Accuracy: 0.8896

# %%
def plot_predictions(model, x_test, y_test, num_images=5):
    predictions = model.predict(x_test)
    plt.figure(figsize=(15, 3*num_images))
    for i in range(num_images):
        plt.subplot(num_images, 1, i+1)
        plt.imshow(x_test[i].reshape(28, 28), cmap=plt.cm.binary)
        pred_label = np.argmax(predictions[i])
        true_label = np.argmax(y_test[i])
        color = 'green' if pred_label == true_label else 'red'
        plt.xlabel(f"Predicted: {class_names[pred_label]} (True: {class_names[true_label]})", color=color)
    plt.show()

print("\nStandard DNN Predictions:")
plot_predictions(dnn_model, x_test_flat, y_test)
print("\nResNet-style DNN Predictions:")
plot_predictions(resnet_model, x_test_flat, y_test)
# Out:
# Standard DNN Predictions:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# ResNet-style DNN Predictions:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
